# %%
import pandas as pd

# %%
#Reading csv files
data1 = pd.read_csv('merged_data.csv')
data2 = pd.read_csv('SocialBlade_type.csv')

# %%
#Using merge function by setting how='left'
df_f = pd.merge(data1, data2, on='Channel', how='left')

# %%
#Displaying result
df_f.head(10)
# Out:
#    Pos                     Channel            Views   Subscriber   Vidoes  \
# 0    1                    T-Series  157,452,055,214  185,000,000   15,528
# 1    2  Cocomelon - Nursery Rhymes  103,803,532,922  113,000,000      654
# 2    3                   SET India   90,768,285,232  107,000,000   59,421
# 3    4                         WWE   59,710,652,499   78,500,000   55,466
# 4    5                 Like Nastya   58,866,363,302   74,700,000      589
# 5    6           ✿ Kids Diana Show   58,484,744,322   80,100,000      891
# 6    7                    Sony SAB   56,242,961,978   52,600,000   37,259
# 7    8                  Movieclips   52,243,427,733   52,900,000   37,366
# 8    9               Vlad and Niki   50,178,997,905   69,000,000      366
# 9   10                Ryan's World   47,553,197,237   29,900,000    2,002
#
#     Published SOCIAL_BLADE_RANK VIDEO_VIEWS_RANK COUNTRY_RANK  MUSIC_RANK   \
# 0  2006-03-13               6th              1st           1st         1st
# ...

# %%
df_f.to_csv("final_result.csv", index= False)
